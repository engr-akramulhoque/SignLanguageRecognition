# %% [markdown]
# # 1. Install & Import Dependences

# %%
# !pip install tensorflow==2.8.1 tensorflow-gpu==2.8.1 opencv-python mediapipe sklearn matplotlib
# !pip install -U scikit-learn

# %%
import cv2
import mediapipe as mp
import numpy as np
from matplotlib import pyplot as plt
import os
import time
import sklearn

# %% [markdown]
# # 2. Keypoints using Mediapipe Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Holistic drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Color Convertion
    # Image not writeable
    image.flags.writeable = False
    # Make prediction
    results = model.process(image)
    # Image is now writeable
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Color Convertion
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    # Draw Face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                              )
    
    #     Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )    
    #     Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             )
    #     Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )

# %%
#mp_drawing.draw_landmarks??

# %%
cap = cv2.VideoCapture(0) # Enter value (1).
# Seting mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # reed feed
        ret, frame = cap.read()

        # make detection
        image, results = mediapipe_detection(frame, holistic)
        
        # draw landmark
        draw_styled_landmarks(image, results)

        # open webcam window
        cv2.imshow("Webcam Window", image)
        # break windows
        if cv2.waitKey(10) & 0xff == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
# drawing hand, pose, face landmarks
# draw_styled_landmarks(image, results)

# %%
# showing matplotlib created image output
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoints Values

# %%
pose=[]
for res in results.pose_landmarks.landmark:
    test = np.array([res.x,res.y,res.z, res.visibility])
    pose.append(test)

# %%
# Define numpy array function.
face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
pose = np.array([[res.x,res.y,res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
# len(face)
# (n=results.face_landmarks) need to change value on shall 17 np.zeros(n)

# %%
def extract_keypoints(results):
    face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    pose = np.array([[res.x,res.y,res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    return np.concatenate([face, pose, lh, rh])
#     return np.concatenate([pose, lh, rh])

# %%
# Check all the kepoints
# extract_keypoints(results).shape

# math 
# 468*3+33*4+21*3+21*3

# %%
# Save Images/Videos on File path with ex .npy
# result_test = extract_keypoints(results)
# np.save('0', result_test)

# it will show the array
# np.load(0.npy)

# %% [markdown]
# # 4. Setup Folders for Data Collection

# %%
# path for exported/Collected data, numpy arrays
DATA_PATH = os.path.join('Collected_Data')

# Actions that we try to detect
actions = np.array(['A','B','C'])

# photos/videos are going to storeing limit 30
no_sequences = 15 # Change to 30
sequences_length = 15 # Change to 30

# %%
# Folder Stucture

# A
## 0 to ## 29 ==30
# B
## 0 to ## 29 ==30
# c
## 0 to ## 29 ==30
# .
# .
# .
# n
## 0 to ## 29 ==30

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect keypoint Values for Training & Testing

# %%
cap = cv2.VideoCapture(0) # Enter value (1).
# Seting mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # loop through actions
    for action in actions:
        # loop through sequences or a videos
        for sequence in range(no_sequences):
            # loop through video length or a sequences length
            for frame_num in range(sequences_length):
                                
                # read feed
                ret, frame = cap.read()

                # make detection
                image, results = mediapipe_detection(frame, holistic)

                # draw landmark
                draw_styled_landmarks(image, results)
                
                # Apply the self folder changing & data collection logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTIONS', (120, 200),
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} video Number{}'.format(action, sequence),(15,12),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.waitKey(2000)
                    
                    
                else:
                    cv2.putText(image, 'Collecting frames for {} video Number{}'.format(action, sequence), (15,12),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                   
                
                # Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # open webcam window
                cv2.imshow("Collection Window", image)
            # break windows
            if cv2.waitKey(10) & 0xff == ord('q'):
                break
                
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 6. Data preprocessing  & Create Lables and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequences_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
# how many shape in each frame
np.array(sequences).shape
# Out:
# (45, 15, 1662)

# %%
x = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
# training & testing
x_train, x_test , y_train, y_test = train_test_split(x, y, test_size=0.25)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# x.shape
# y.shape
# actions.shape[0]

# %%
# finding labels
res =[.7, 0.2, 0.1]
actions[np.argmax(res)]
# Out:
# 'A'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 133ms/step - loss: 0.4831 - categorical_accuracy: 0.8095
# Epoch 2/100
# 2/2 [==============================] - 0s 147ms/step - loss: 1.3454 - categorical_accuracy: 0.6905
# Epoch 3/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.7409 - categorical_accuracy: 0.7619
# Epoch 4/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.4201 - categorical_accuracy: 0.8333
# Epoch 5/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.5199 - categorical_accuracy: 0.7143
# Epoch 6/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.5684 - categorical_accuracy: 0.6667
# Epoch 7/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.6220 - categorical_accuracy: 0.7143
# Epoch 8/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.5884 - categorical_accuracy: 0.6429
# Epoch 9/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.6060 - categorical_accuracy: 0.6905
# Epoch 10/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.6224 - categorical_accuracy: 0.6667
# Epoch 11/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.4801 - categorical_accuracy: 0.8095
# Epoch 12/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5180 - categorical_accuracy: 0.6667
# Epoch 13/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.7016 - categorical_accuracy: 0.6905
# Epoch 14/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.4975 - categorical_accuracy: 0.8333
# Epoch 15/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.5743 - categorical_accuracy: 0.7381
# Epoch 16/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.4807 - categorical_accuracy: 0.7619
# Epoch 17/100
# 2/2 [==============================] - 0s 147ms/step - loss: 0.5853 - categorical_accuracy: 0.7381
# Epoch 18/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.3396 - categorical_accuracy: 0.8810
# Epoch 19/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.7807 - categorical_accuracy: 0.7619
# Epoch 20/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.4586 - categorical_accuracy: 0.7857
# Epoch 21/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4532 - categorical_accuracy: 0.8333
# Epoch 22/100
# 2/2 [==============================] - 0s 97ms/step - loss: 0.4520 - categorical_accuracy: 0.8333
# Epoch 23/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.4104 - categorical_accuracy: 0.9048
# Epoch 24/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.4149 - categorical_accuracy: 0.8095
# Epoch 25/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.4055 - categorical_accuracy: 0.7857
# Epoch 26/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.3951 - categorical_accuracy: 0.8571
# Epoch 27/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.3627 - categorical_accuracy: 0.8333
# Epoch 28/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.3878 - categorical_accuracy: 0.8333
# Epoch 29/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.4150 - categorical_accuracy: 0.8095
# Epoch 30/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.4558 - categorical_accuracy: 0.8095
# Epoch 31/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2854 - categorical_accuracy: 0.9048
# Epoch 32/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5857 - categorical_accuracy: 0.6905
# Epoch 33/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.3218 - categorical_accuracy: 0.9048
# Epoch 34/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5318 - categorical_accuracy: 0.7381
# Epoch 35/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.8643 - categorical_accuracy: 0.9286
# Epoch 36/100
# 2/2 [==============================] - 0s 137ms/step - loss: 1.0583 - categorical_accuracy: 0.8810
# Epoch 37/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.8023 - categorical_accuracy: 0.8571
# Epoch 38/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5636 - categorical_accuracy: 0.6429
# Epoch 39/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.6927 - categorical_accuracy: 0.7381
# Epoch 40/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.6741 - categorical_accuracy: 0.6190
# Epoch 41/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5940 - categorical_accuracy: 0.7857
# Epoch 42/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.6060 - categorical_accuracy: 0.7619
# Epoch 43/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.4461 - categorical_accuracy: 0.8095
# Epoch 44/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5644 - categorical_accuracy: 0.7381
# Epoch 45/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.7859 - categorical_accuracy: 0.5238
# Epoch 46/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.6505 - categorical_accuracy: 0.7143
# Epoch 47/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.4573 - categorical_accuracy: 0.7857
# Epoch 48/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.7852 - categorical_accuracy: 0.5714
# Epoch 49/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.4478 - categorical_accuracy: 0.8571
# Epoch 50/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.8859 - categorical_accuracy: 0.6667
# Epoch 51/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.8548 - categorical_accuracy: 0.8095
# Epoch 52/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.4850 - categorical_accuracy: 0.8571
# Epoch 53/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.7733 - categorical_accuracy: 0.5714
# Epoch 54/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.7549 - categorical_accuracy: 0.6667
# Epoch 55/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.7101 - categorical_accuracy: 0.5952
# Epoch 56/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.6262 - categorical_accuracy: 0.7857
# Epoch 57/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.5184 - categorical_accuracy: 0.8095
# Epoch 58/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5243 - categorical_accuracy: 0.7857
# Epoch 59/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.4797 - categorical_accuracy: 0.8095
# Epoch 60/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4675 - categorical_accuracy: 0.7857
# Epoch 61/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.4319 - categorical_accuracy: 0.7857
# Epoch 62/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.3801 - categorical_accuracy: 0.8095
# Epoch 63/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.3934 - categorical_accuracy: 0.8571
# Epoch 64/100
# 2/2 [==============================] - 0s 131ms/step - loss: 0.3413 - categorical_accuracy: 0.9048
# Epoch 65/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.3292 - categorical_accuracy: 0.8571
# Epoch 66/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.3486 - categorical_accuracy: 0.8810
# Epoch 67/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.3416 - categorical_accuracy: 0.8810
# Epoch 68/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.3196 - categorical_accuracy: 0.8571
# Epoch 69/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2852 - categorical_accuracy: 0.8810
# Epoch 70/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.3354 - categorical_accuracy: 0.8571
# Epoch 71/100
# 2/2 [==============================] - 0s 131ms/step - loss: 0.7137 - categorical_accuracy: 0.7143
# Epoch 72/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.3555 - categorical_accuracy: 0.8571
# Epoch 73/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.3950 - categorical_accuracy: 0.8333
# Epoch 74/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.2957 - categorical_accuracy: 0.8571
# Epoch 75/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.3656 - categorical_accuracy: 0.7619
# Epoch 76/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.2728 - categorical_accuracy: 0.9048
# Epoch 77/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.2748 - categorical_accuracy: 0.9048
# Epoch 78/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.2584 - categorical_accuracy: 0.9048
# Epoch 79/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.2592 - categorical_accuracy: 0.8810
# Epoch 80/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2289 - categorical_accuracy: 0.9048
# Epoch 81/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2240 - categorical_accuracy: 0.9286
# Epoch 82/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.2707 - categorical_accuracy: 0.8571
# Epoch 83/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2269 - categorical_accuracy: 0.9048
# Epoch 84/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2695 - categorical_accuracy: 0.9048
# Epoch 85/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.2581 - categorical_accuracy: 0.8810
# Epoch 86/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.2259 - categorical_accuracy: 0.9048
# Epoch 87/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.2302 - categorical_accuracy: 0.9048
# Epoch 88/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.1984 - categorical_accuracy: 0.9048
# Epoch 89/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1937 - categorical_accuracy: 0.9286
# Epoch 90/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.1820 - categorical_accuracy: 0.9048
# Epoch 91/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.2704 - categorical_accuracy: 0.8333
# Epoch 92/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2023 - categorical_accuracy: 0.8810
# Epoch 93/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1939 - categorical_accuracy: 0.9048
# Epoch 94/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1849 - categorical_accuracy: 0.9286
# Epoch 95/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.2065 - categorical_accuracy: 0.9286
# Epoch 96/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1760 - categorical_accuracy: 0.9286
# Epoch 97/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.1371 - categorical_accuracy: 0.9286
# Epoch 98/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1954 - categorical_accuracy: 0.9286
# Epoch 99/100
# 2/2 [==============================] - 0s 221ms/step - loss: 0.1851 - categorical_accuracy: 0.8810
# Epoch 100/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.3210 - categorical_accuracy: 0.9048

# %%
# for training model
# inside command promt

# cd F:\Jupyter_notebook\SignLanguageDetection\Logs\train
# tensorboard --logdir=.

# now open
# http://localhost:6006/

# %%
# model train summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 15, 128)           916992
#
#  lstm_1 (LSTM)               (None, 15, 64)            49408
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1,005,763
# Trainable params: 1,005,763
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make predictions

# %%
res = model.predict(x_test)

# %%
actions[np.argmax(res[0])]
# Out:
# 'B'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'C'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
# delete and reload
# del model

# %%
# reload model
# model.load_weights(action.h5)

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(x_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat,axis=1).tolist()

# %%
ytrue
# Out:
# [2, 2, 2]

# %%
# multilabel_confusion_matrix?

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[2, 1],
#         [0, 0]],
#
#        [[0, 0],
#         [1, 2]]], dtype=int64)

# %%
# score 1 is 100% accuracy of the model
accuracy_score(ytrue, yhat)
accur = accuracy_score(ytrue, yhat)

# %%
print(accur)
# Out:
# 0.6666666666666666

# %%
plt.plot(yhat)

# %% [markdown]
# # 11. Test in Real Time

# %%
# testing sequences
np.expand_dims(x_test[0], axis=0)
# Out:
# array([[[ 0.34584001,  0.77336687, -0.04284335, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.34391433,  0.76799572, -0.04199892, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.34446988,  0.77073622, -0.04233174, ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 0.354976  ,  0.75733107, -0.04343014, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.35389858,  0.75800335, -0.04297066, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.3521964 ,  0.7609027 , -0.04410237, ...,  0.        ,
#           0.        ,  0.        ]]])

# %%
# (num_sequences,30,1662)

# %%
model.predict(np.expand_dims(x_test[0], axis=0))
# Out:
# array([[0.00112396, 0.99218833, 0.00668768]], dtype=float32)

# %%
from scipy import stats

# %%
# probabitity vizualization function
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.imshow(prob_viz(res, actions, image, colors))

# %%
model.predict(np.expand_dims(sequence, axis=0))[0].shape
# Out:
# (3,)

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
#             print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('prediction window', image)
        print(accur)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666

# %%
plt.plot(yhat)

# %%
# if we get an error we need to run this shell
cap.release()
cv2.destroyAllWindows()

# %%
plt.plot(res)
